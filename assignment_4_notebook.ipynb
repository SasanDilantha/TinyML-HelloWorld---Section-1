# %% [markdown]
# <a href="https://colab.research.google.com/github/SasanDilantha/TinyML-HelloWorld---Section-1/blob/main/assignment_4_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4 - TinyML HelloWorld - Section 1
# Based on the **hello_world** example from [TensorFlow Lite for MicroControllers](https://github.com/tensorflow/tflite-micro/tree/main/tensorflow/lite/micro/examples/hello_world).
#
# © SkillSurf 2024

# %% [markdown]
# ## Introduction
#
# In this section you will train a Tensorflow model to a set of sinusoidal data. First you will synthesize the data to mimic a sine wave. Then you can build your own tensorflow model and fit the model to the generated data. Start by importing the relevant modules.

# %% [markdown]
# ## Import modules

# %%
# Import Tensorflow and NumPy
# Set random seed to get reproducible results
import numpy as np
np.random.seed(1)

import tensorflow as tf
tf.random.set_seed(1)

# %%
# Make sure Tensorflow 2 is installed on the system
print(tf.__version__)
# Out:
# 2.17.0

# %%
import os
from tensorflow import keras
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ##  Create the Dataset
#
# You can use NumPy to generate a sinewave data and add some gaussian noise to make the data more realistic. The dataset will consist of 1000 datapoints (x-values) and relevant y-values. The following code creates a sine wave dataset.

# %%
# Number of sample datapoints
SAMPLES = 1000

# Generate a uniformly distributed set of random numbers in the range from
# 0 to 2π, which covers a complete sine wave oscillation
x_values = np.random.uniform(
    low=0, high=2*math.pi, size=SAMPLES).astype(np.float32)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

# Calculate the corresponding sine values
y_values = np.sin(x_values).astype(np.float32)

# Plot the data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# Next add noise to the data to make the data more realistic. (In real-life the data we obtain usually get contaminated by different kinds of noise.)

# %%
# Add a small random number to each y value
y_values += 0.1 * np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Pre-process data (Graded)
#
# The dataset has been given, now you will have to split this dataset into train, validation and test subsets. The following table shows the split ratio you should be using.
#
# | Split | Percentage |
# |----------|----------|
# | Train | 60% |
# | Validation | 20% |
# | Test | 20% |
#
# You may use the `np.split()` function for obtaining 3 splits of data from one line of code. You have to provide the indiced of points which the dataset is divided. The second argument to `np.split()` is an array of indices where the data will be split. We provide two indices, so the data will be divided into three chunks. For more clarification look into the documentation of [np.split()](https://numpy.org/doc/stable/reference/generated/numpy.split.html).
#
#
# ### Exercise 1
# Complete the code below to split the data accordingly and plot all three splits in the same plot.

# %%
# Define the indices where the dataset will get chopped (TODO)
TRAIN_SPLIT = int(0.6 * len(x_values))
TEST_SPLIT = int(0.2 * len(x_values) + TRAIN_SPLIT)

# Split the data into train, validation and test sets (TODO)
x_train, x_test, x_validate = x_values[:TRAIN_SPLIT], x_values[TRAIN_SPLIT:TEST_SPLIT], x_values[TEST_SPLIT:]
y_train, y_test, y_validate = y_values[:TRAIN_SPLIT], y_values[TRAIN_SPLIT:TEST_SPLIT], y_values[TEST_SPLIT:]

# Use np.split to chop the data into three parts (TODO)
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'g.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Build the Model (Graded)
#
# You have successfully pre-processed the dataset. Next you will have to define build the Tensorflow model using Keras. You may use the Tensorflow Keras Sequential API. Please refer to the official [Keras documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers) for further information. Use the below architecture to design your the model.
#
# - Input layer
# - 2 Dense layers each consisting of 16 hidden units and ReLU activation - [keras.layers.Dense()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)
# - Output layer with 1 unit
#
# ### Exercise 2
# Design the sequential model according to the specifications above.

# %%
# Define the model using the Keras API (TODO)
model = keras.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(1,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1)
])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-7632cc042e1e> in <cell line: 2>()
#       1 # Define the model using the Keras API (TODO)
# ----> 2 model = keras.Sequential([
#       3     keras.layers.Dense(16, activation='relu', input_shape=(1,)),
#       4     keras.layers.Dense(16, activation='relu'),
#       5     keras.layers.Dense(1)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/lazy_loader.py in __getattr__(self, item)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/lazy_loader.py in _load(self)
#      50     # Update this object's dict so that if someone keeps a reference to the
#      51     #   LazyLoader, lookups are efficient (__getattr__ is only called on lookups
# ---> 52     #   that fail).
#      53     self.__dict__.update(module.__dict__)
#      54
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'keras._tf_keras'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Now that you have created the model, specify the optimizer, loss function and acuracy metrics. Use the below,
#
# - Optimizer: Adam
# - Loss function: Mean Squared Error (MSE)
# - Metric: Mean Absolute Error (MAE)
#
# You may use `model.compile()` and read the [tf.keras.Sequential](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential) documentation for this.
#
# ### Exercise 3
# Set the optimizer and loss function details as specified as above.

# %%
# Compile the model using a standard optimizer and loss function for regression
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %%
# Get model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │              32 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 321 (1.25 KB)
#  Trainable params: 321 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train the Model (Graded)
#
# Fit the model to the data using `model.fit()`. Train for 500 epochs with a batch size of 64. Use only the train and validation sets during training.
#
# ### Exercise 4
# Fit the model to the data. Keep track of the losses and metrics using `history` object.

# %%
# Fit the model to the data and keep track of losses (TODO)
history = model.fit(
    x_train,
    y_train,
    validation_data=(x_validate, y_validate),
    epochs=500,
    batch_size=64
)
# Out:
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.8557 - mae: 0.8107 - val_loss: 0.6056 - val_mae: 0.7093
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5429 - mae: 0.6584 - val_loss: 0.4887 - val_mae: 0.6062
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4684 - mae: 0.5890 - val_loss: 0.4655 - val_mae: 0.5840
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4490 - mae: 0.5646 - val_loss: 0.4386 - val_mae: 0.5694
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4219 - mae: 0.5524 - val_loss: 0.4159 - val_mae: 0.5584
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3994 - mae: 0.5442 - val_loss: 0.3964 - val_mae: 0.5474
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3795 - mae: 0.5312 - val_loss: 0.3756 - val_mae: 0.5328
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3597 - mae: 0.5149 - val_loss: 0.3561 - val_mae: 0.5184
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3415 - mae: 0.4997 - val_loss: 0.3386 - val_mae: 0.5063
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3248 - mae: 0.4871 - val_loss: 0.3225 - val_mae: 0.4955
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3091 - mae: 0.4757 - val_loss: 0.3074 - val_mae: 0.4850
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2943 - mae: 0.4643 - val_loss: 0.2927 - val_mae: 0.4741
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2800 - mae: 0.4531 - val_loss: 0.2774 - val_mae: 0.4628
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2641 - mae: 0.4408 - val_loss: 0.2609 - val_mae: 0.4507
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2484 - mae: 0.4284 - val_loss: 0.2478 - val_mae: 0.4395
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2355 - mae: 0.4173 - val_loss: 0.2357 - val_mae: 0.4280
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2242 - mae: 0.4075 - val_loss: 0.2254 - val_mae: 0.4190
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2142 - mae: 0.3988 - val_loss: 0.2164 - val_mae: 0.4106
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2053 - mae: 0.3908 - val_loss: 0.2084 - val_mae: 0.4027
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1975 - mae: 0.3834 - val_loss: 0.2015 - val_mae: 0.3957
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1907 - mae: 0.3766 - val_loss: 0.1954 - val_mae: 0.3889
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1842 - mae: 0.3697 - val_loss: 0.1866 - val_mae: 0.3790
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1767 - mae: 0.3619 - val_loss: 0.1820 - val_mae: 0.3737
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1719 - mae: 0.3562 - val_loss: 0.1777 - val_mae: 0.3683
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1670 - mae: 0.3500 - val_loss: 0.1733 - val_mae: 0.3615
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1629 - mae: 0.3449 - val_loss: 0.1700 - val_mae: 0.3565
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.
- val_loss: 0.0126 - val_mae: 0.0903
# Epoch 374/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - mae: 0.0959 - val_loss: 0.0125 - val_mae: 0.0902
# Epoch 375/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0142 - mae: 0.0958 - val_loss: 0.0125 - val_mae: 0.0901
# Epoch 376/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - mae: 0.0958 - val_loss: 0.0125 - val_mae: 0.0899
# Epoch 377/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - mae: 0.0957 - val_loss: 0.0124 - val_mae: 0.0898
# Epoch 378/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0141 - mae: 0.0957 - val_loss: 0.0124 - val_mae: 0.0897
# Epoch 379/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0141 - mae: 0.0956 - val_loss: 0.0124 - val_mae: 0.0896
# Epoch 380/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0141 - mae: 0.0956 - val_loss: 0.0124 - val_mae: 0.0895
# Epoch 381/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0141 - mae: 0.0955 - val_loss: 0.0123 - val_mae: 0.0893
# Epoch 382/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0141 - mae: 0.0954 - val_loss: 0.0123 - val_mae: 0.0892
# Epoch 383/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mae: 0.0954 - val_loss: 0.0123 - val_mae: 0.0891
# Epoch 384/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - mae: 0.0953 - val_loss: 0.0122 - val_mae: 0.0890
# Epoch 385/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mae: 0.0953 - val_loss: 0.0122 - val_mae: 0.0889
# Epoch 386/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mae: 0.0952 - val_loss: 0.0122 - val_mae: 0.0889
# Epoch 387/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mae: 0.0952 - val_loss: 0.0122 - val_mae: 0.0888
# Epoch 388/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0140 - mae: 0.0951 - val_loss: 0.0122 - val_mae: 0.0887
# Epoch 389/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0139 - mae: 0.0951 - val_loss: 0.0121 - val_mae: 0.0886
# Epoch 390/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0139 - mae: 0.0950 - val_loss: 0.0121 - val_mae: 0.0885
# Epoch 391/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139 - mae: 0.0950 - val_loss: 0.0121 - val_mae: 0.0884
# Epoch 392/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139 - mae: 0.0949 - val_loss: 0.0121 - val_mae: 0.0883
# Epoch 393/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0139 - mae: 0.0949 - val_loss: 0.0120 - val_mae: 0.0883
# Epoch 394/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139 - mae: 0.0949 - val_loss: 0.0120 - val_mae: 0.0882
# Epoch 395/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0138 - mae: 0.0948 - val_loss: 0.0120 - val_mae: 0.0881
# Epoch 396/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0138 - mae: 0.0948 - val_loss: 0.0120 - val_mae: 0.0880
# Epoch 397/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0138 - mae: 0.0948 - val_loss: 0.0120 - val_mae: 0.0879
# Epoch 398/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0138 - mae: 0.0947 - val_loss: 0.0119 - val_mae: 0.0879
# Epoch 399/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - mae: 0.0947 - val_loss: 0.0119 - val_mae: 0.0878
# Epoch 400/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0138 - mae: 0.0946 - val_loss: 0.0119 - val_mae: 0.0877
# Epoch 401/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - mae: 0.0946 - val_loss: 0.0119 - val_mae: 0.0877
# Epoch 402/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138 - mae: 0.0946 - val_loss: 0.0119 - val_mae: 0.0876
# Epoch 403/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - mae: 0.0945 - val_loss: 0.0119 - val_mae: 0.0876
# Epoch 404/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137 - mae: 0.0945 - val_loss: 0.0118 - val_mae: 0.0875
# Epoch 405/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0137 - mae: 0.0944 - val_loss: 0.0118 - val_mae: 0.0874
# Epoch 406/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0137 - mae: 0.0944 - val_loss: 0.0118 - val_mae: 0.0873
# Epoch 407/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137 - mae: 0.0944 - val_loss: 0.0118 - val_mae: 0.0873
# Epoch 408/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137 - mae: 0.0943 - val_loss: 0.0118 - val_mae: 0.0872
# Epoch 409/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - mae: 0.0943 - val_loss: 0.0118 - val_mae: 0.0872
# Epoch 410/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0137 - mae: 0.0943 - val_loss: 0.0117 - val_mae: 0.0871
# Epoch 411/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0136 - mae: 0.0943 - val_loss: 0.0117 - val_mae: 0.0871
# Epoch 412/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0136 - mae: 0.0942 - val_loss: 0.0117 - val_mae: 0.0870
# Epoch 413/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0136 - mae: 0.0942 - val_loss: 0.0117 - val_mae: 0.0870
# Epoch 414/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136 - mae: 0.0942 - val_loss: 0.0117 - val_mae: 0.0869
# Epoch 415/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0941 - val_loss: 0.0117 - val_mae: 0.0869
# Epoch 416/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0941 - val_loss: 0.0117 - val_mae: 0.0868
# Epoch 417/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0941 - val_loss: 0.0116 - val_mae: 0.0868
# Epoch 418/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0941 - val_loss: 0.0116 - val_mae: 0.0867
# Epoch 419/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0940 - val_loss: 0.0116 - val_mae: 0.0867
# Epoch 420/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - mae: 0.0940 - val_loss: 0.0116 - val_mae: 0.0866
# Epoch 421/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - mae: 0.0940 - val_loss: 0.0116 - val_mae: 0.0866
# Epoch 422/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0940 - val_loss: 0.0116 - val_mae: 0.0866
# Epoch 423/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0939 - val_loss: 0.0116 - val_mae: 0.0865
# Epoch 424/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0939 - val_loss: 0.0116 - val_mae: 0.0865
# Epoch 425/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0939 - val_loss: 0.0115 - val_mae: 0.0865
# Epoch 426/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0939 - val_loss: 0.0115 - val_mae: 0.0864
# Epoch 427/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - mae: 0.0938 - val_loss: 0.0115 - val_mae: 0.0864
# Epoch 428/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0938 - val_loss: 0.0115 - val_mae: 0.0863
# Epoch 429/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0938 - val_loss: 0.0115 - val_mae: 0.0863
# Epoch 430/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0938 - val_loss: 0.0115 - val_mae: 0.0862
# Epoch 431/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - mae: 0.0938 - val_loss: 0.0115 - val_mae: 0.0862
# Epoch 432/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134 - mae: 0.0937 - val_loss: 0.0115 - val_mae: 0.0861
# Epoch 433/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - mae: 0.0937 - val_loss: 0.0114 - val_mae: 0.0861
# Epoch 434/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0937 - val_loss: 0.0114 - val_mae: 0.0860
# Epoch 435/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0937 - val_loss: 0.0114 - val_mae: 0.0860
# Epoch 436/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0936 - val_loss: 0.0114 - val_mae: 0.0860
# Epoch 437/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - mae: 0.0936 - val_loss: 0.0114 - val_mae: 0.0860
# Epoch 438/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0936 - val_loss: 0.0114 - val_mae: 0.0859
# Epoch 439/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - mae: 0.0936 - val_loss: 0.0114 - val_mae: 0.0860
# Epoch 440/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - mae: 0.0935 - val_loss: 0.0114 - val_mae: 0.0860
# Epoch 441/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - mae: 0.0935 - val_loss: 0.0114 - val_mae: 0.0860
# Epoch 442/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0935 - val_loss: 0.0114 - val_mae: 0.0859
# Epoch 443/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134 - mae: 0.0935 - val_loss: 0.0114 - val_mae: 0.0859
# Epoch 444/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0935 - val_loss: 0.0114 - val_mae: 0.0859
# Epoch 445/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0934 - val_loss: 0.0114 - val_mae: 0.0858
# Epoch 446/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mae: 0.0934 - val_loss: 0.0113 - val_mae: 0.0857
# Epoch 447/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - mae: 0.0934 - val_loss: 0.0113 - val_mae: 0.0857
# Epoch 448/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133 - mae: 0.0934 - val_loss: 0.0113 - val_mae: 0.0856
# Epoch 449/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - mae: 0.0933 - val_loss: 0.0113 - val_mae: 0.0856
# Epoch 450/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - mae: 0.0933 - val_loss: 0.0113 - val_mae: 0.0856
# Epoch 451/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mae: 0.0933 - val_loss: 0.0113 - val_mae: 0.0855
# Epoch 452/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mae: 0.0933 - val_loss: 0.0113 - val_mae: 0.0857
# Epoch 453/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mae: 0.0931 - val_loss: 0.0113 - val_mae: 0.0854
# Epoch 454/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mae: 0.0934 - val_loss: 0.0113 - val_mae: 0.0856
# Epoch 455/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - mae: 0.0932 - val_loss: 0.0112 - val_mae: 0.0854
# Epoch 456/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - mae: 0.0933 - val_loss: 0.0113 - val_mae: 0.0855
# Epoch 457/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mae: 0.0932 - val_loss: 0.0113 - val_mae: 0.0855
# Epoch 458/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - mae: 0.0931 - val_loss: 0.0113 - val_mae: 0.0854
# Epoch 459/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mae: 0.0932 - val_loss: 0.0113 - val_mae: 0.0854
# Epoch 460/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mae: 0.0931 - val_loss: 0.0113 - val_mae: 0.0854
# Epoch 461/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0132 - mae: 0.0931 - val_loss: 0.0112 - val_mae: 0.0853
# Epoch 462/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0132 - mae: 0.0931 - val_loss: 0.0112 - val_mae: 0.0853
# Epoch 463/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mae: 0.0931 - val_loss: 0.0112 - val_mae: 0.0853
# Epoch 464/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - mae: 0.0930 - val_loss: 0.0112 - val_mae: 0.0852
# Epoch 465/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - mae: 0.0930 - val_loss: 0.0112 - val_mae: 0.0852
# Epoch 466/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0132 - mae: 0.0930 - val_loss: 0.0112 - val_mae: 0.0852
# Epoch 467/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - mae: 0.0929 - val_loss: 0.0112 - val_mae: 0.0852
# Epoch 468/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - mae: 0.0929 - val_loss: 0.0112 - val_mae: 0.0851
# Epoch 469/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - mae: 0.0929 - val_loss: 0.0112 - val_mae: 0.0851
# Epoch 470/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - mae: 0.0929 - val_loss: 0.0112 - val_mae: 0.0851
# Epoch 471/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mae: 0.0929 - val_loss: 0.0112 - val_mae: 0.0851
# Epoch 472/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - mae: 0.0928 - val_loss: 0.0112 - val_mae: 0.0851
# Epoch 473/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mae: 0.0928 - val_loss: 0.0112 - val_mae: 0.0850
# Epoch 474/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - mae: 0.0928 - val_loss: 0.0112 - val_mae: 0.0850
# Epoch 475/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mae: 0.0928 - val_loss: 0.0112 - val_mae: 0.0850
# Epoch 476/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0928 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 477/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0928 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 478/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0927 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 479/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0131 - mae: 0.0927 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 480/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0927 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 481/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0927 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 482/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0927 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 483/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0927 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 484/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0926 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 485/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0927 - val_loss: 0.0112 - val_mae: 0.0849
# Epoch 486/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0926 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 487/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0926 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 488/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0926 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 489/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0926 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 490/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0926 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 491/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0926 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 492/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0926 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 493/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0926 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 494/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0131 - mae: 0.0925 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 495/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0925 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 496/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0925 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 497/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0131 - mae: 0.0925 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 498/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0925 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 499/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0925 - val_loss: 0.0111 - val_mae: 0.0849
# Epoch 500/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0924 - val_loss: 0.0111 - val_mae: 0.0849

# %% [markdown]
# ## Plotting Loss Curves
#
# The following code plots the loss curves (Training loss and validation loss) with each epoch. The loss curve can be used to check whether your model converged correctly.
#
# <img src="https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/images/04-loss-curves-overfitting-underfitting-ideal.jpg" alt="Loss Curves" width="600"/>
#
# Run the below cell and make sure your loss curves appear to be as the ones on the right of the below image. For more reading, refer to [this](https://www.learnpytorch.io/04_pytorch_custom_datasets/#8-what-should-an-ideal-loss-curve-look-like).

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

# Exclude the first few epochs so the graph is easier to read
SKIP = 100

plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
mae = history.history['mae']
val_mae = history.history['val_mae']

plt.plot(epochs[SKIP:], mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# ## Predict using model (Graded)
#
# Use `model.predict()` to predict values for all data in test set and plot it against true values. You may refer to this [documentation](https://www.tensorflow.org/guide/keras/training_with_built_in_methods) for more information.
#
# ### Exercise 5
# Predict y values for test data and plot it with true values.

# %%
# Make predictions based on our test dataset (TODO)
predictions = model.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted')
plt.legend()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# ### Exercise 6
# The predicted graph is not nearly as smooth enough to be a sine. Rather it may look like a piecewise combination of linear functions. Briefly explain how you can make this more smoother and identical to an actual sine wave.

# %% [markdown]
# ##### Explanation:
#
# * Increse the dense layer count and hidden units then model prediction will very accurate.
# * Increse the training and testion data count and traing epocs and batch size
# * Not only that, we can use trigonometric like non-linear functions use for improve the model

# %% [markdown]
# ## Get weights
#
# Now you will extract the weight matrices from the model. This step is in order to convert these weight matrices to C++ files that will be embedded in the Microcontroller.

# %%
# Extract weights and biases as Numpy arrays
W1, b1 = model.layers[0].get_weights()
W2, b2 = model.layers[1].get_weights()
W3, b3 = model.layers[2].get_weights()

# %%
print(W1.shape, b1.shape)
print(W2.shape, b2.shape)
print(W3.shape, b3.shape)
# Out:
# (1, 16) (16,)
# (16, 16) (16,)
# (16, 1) (1,)

# %% [markdown]
# The following code performs the forward propagation of the model manually using NumPy matrix multiplication. Run the following code to make sure the model's prediction and manual prediction is same.

# %%
xs = x_test

# %%
# This is what the TF model does internally:
ys = []
for x in xs:
    x = np.array([x])       # x should be array
    h1 = x @ W1 + b1        # dense layer
    h1 = np.maximum(0, h1)  # ReLU
    h2 = h1 @ W2 + b2       # dense layer
    h2 = np.maximum(0, h2)  # ReLU
    h3 = h2 @ W3 + b3       # dense layer
    ys.append(h3)

ys = np.stack(ys)

# %%
# Are our predictions the same as TF's predictions?
# This should print 0 if the results are close enough.
np.sum(np.abs(ys - predictions) > 1e-6)
# Out:
# 0

# %% [markdown]
# ## Export the weights for C++
#
# The following code compresses the weights and biases into a C++ format which will be stored in the Microcontroller's FLASH memory. Copy the generated output and paste in file named `model_data.cpp`.

# %%
# Note that we transpose W2. This makes the inner loop for the
# matrix multiplication a little simpler.

names = ["W1_data", "b1_data", "W2_data", "b2_data", "W3_data", "b3_data"]
arrays = [W1, b1, W2.T, b2, W3, b3]

# %%
# Copy this into model_data.cpp:

for name, array in zip(names, arrays):
    print("const float %s[] PROGMEM = {" % name)
    print("   ", ", ".join([str(x) + "f" for x in array.flatten()]))
    print("};\n")
# Out:
# const float W1_data[] PROGMEM = {
#     -0.13033831f, 0.15807976f, 0.047466207f, 0.1741751f, -0.43326992f, -0.3296951f, -0.21207553f, 0.31905758f, -0.30064255f, -0.5003404f, -0.027442515f, 0.19630963f, 0.505638f, -0.04807633f, 0.1403548f, 0.6426892f
# };
#
# const float b1_data[] PROGMEM = {
#     0.0f, -0.29400393f, 0.7430755f, -0.04891843f, 0.0f, 0.0f, 0.0f, 0.12763998f, 0.0f, 0.0f, 0.0f, -0.19404739f, 0.34626523f, 0.0f, -0.33282664f, -0.9754633f
# };
#
# const float W2_data[] PROGMEM = {
#     0.30217853f, -0.28676504f, 0.269064f, 0.059374426f, 0.19415948f, 0.3137001f, 0.17202356f, 0.32667384f, -0.20090146f, -0.42683253f, -0.36876637f, -0.41514626f, 0.23531355f, -0.27561027f, -0.031965975f, -0.3307193f, -0.29141232f, 0.01031821f, 0.16652523f, 0.26001862f, -0.3607261f, -0.3632834f, -0.28219223f, 0.27087688f, -0.33891153f, 0.1627728f, 0.29045734f, -0.18297446f, -0.14256622f, -0.27627623f, 0.50617355f, 0.19312917f, -0.3049168f, 0.15222633f, 0.21541429f, -0.37303406f, -0.38243657f, -0.40082538f, 0.4173493f, -0.3250735f, -0.16147643f, -0.43167236f, -0.22726966f, 0.087347f, -0.17389096f, 0.16680226f, -0.13698241f, -0.2150766f, -0.3670421f, -0.30136734f, 0.21758035f, -0.056857627f, 0.18429795f, 0.3584381f, -0.33519214f, 0.009100388f, 0.2834054f, -0.23676986f, -0.04238975f, 0.30362746f, 0.20358478f, -0.38633734f, -0.45054123f, 0.11350635f, -0.100456625f, 0.33532128f, 0.20113538f, 0.120558366f, -0.31319034f, 0.042645663f, -0.33536768f, 0.34179944f, -0.0577299f, -0.19742182f, -0.12866277f, 0.14358594f, 0.24294734f, 0.3502957f, -0.1856818f, -0.30470094f, 0.046243608f, 0.28912655f, -0.45155948f, -0.31877297f, -0.41438922f, -0.16557044f, -0.16284215f, 0.3028934f, 0.35288224f, -0.12860793f, -0.3223387f, -0.22322579f, 0.33480746f, 0.39436308f, 0.42393246f, 0.46264082f, 0.4245765f, 0.2124645f, 0.33838162f, -0.15235737f, 0.33687845f, -0.30831397f, -0.3619067f, -0.18183416f, -0.049708188f, 0.105620295f, -0.35418192f, 0.13448898f, 0.46281505f,